# %%
qnorm(0.975,0,1)
# Out:
# [1] 1.959964

# %%
qnorm(0.025,0,1)
# Out:
# [1] -1.959964

# %%
2*(1-pnorm(2.11))
# Out:
# [1] 0.03485836

# %%
x <- seq(0:30)
curve(dchisq(x,1), 0, 30, col=2, ylab="f(x)")
curve(dchisq(x,2), 0, 30, col=3, add=TRUE)
curve(dchisq(x,3), 0, 30, col=4, add=TRUE)
curve(dchisq(x,4), 0, 30, col=5, add=TRUE)
curve(dchisq(x,5), 0, 30, col=6, add=TRUE)
# Out:
# plot without title

# %%
x <- seq(0:30)
curve(dchisq(x,1), 0, 30, col=2, ylab="f(x)")
curve(dchisq(x,3), 0, 30, col=3, add=TRUE)
curve(dchisq(x,5), 0, 30, col=4, add=TRUE)
curve(dchisq(x,10), 0, 30, col=5, add=TRUE)
curve(dchisq(x,20), 0, 30, col=6, add=TRUE)
# Out:
# plot without title
