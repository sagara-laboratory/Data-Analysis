# %%
kenroku<-read.table("kenroku.dat", header=T)

# %%
attach(kenroku)

# %%
kenroku
# Out:
#     KENROKU
# H20 1822336
# H21 1832220
# H22 1637977
# H23 1549448
# H24 1732992
# H25 1726743
# H26 2037240
# H27 3089219
# H28 2911660
# H29 2799636
# H30 2748174
# R1  2591010
# R2  1021881

# %%
KENROKU
# Out:
#  [1] 1822336 1832220 1637977 1549448 1732992 1726743 2037240 3089219 2911660
# [10] 2799636 2748174 2591010 1021881

# %%
hist(KENROKU)
# Out:
# Plot with title "Histogram of KENROKU"

# %%
plot(KENROKU)
# Out:
# plot without title

# %%
plot(KENROKU, type="p")
# Out:
# plot without title

# %%
plot(KENROKU, type="l")
# Out:
# plot without title

# %%
plot(KENROKU, type="b")
# Out:
# plot without title

# %%
plot(KENROKU, type="l", col=4)
# Out:
# plot without title

# %%
plot(KENROKU, type="b", col="green")
# Out:
# plot without title

# %%
colours()
# Out:
#   [1] "white"                "aliceblue"            "antiquewhite"
#   [4] "antiquewhite1"        "antiquewhite2"        "antiquewhite3"
#   [7] "antiquewhite4"        "aquamarine"           "aquamarine1"
#  [10] "aquamarine2"          "aquamarine3"          "aquamarine4"
#  [13] "azure"                "azure1"               "azure2"
#  [16] "azure3"               "azure4"               "beige"
#  [19] "bisque"               "bisque1"              "bisque2"
#  [22] "bisque3"              "bisque4"              "black"
#  [25] "blanchedalmond"       "blue"                 "blue1"
#  [28] "blue2"                "blue3"                "blue4"
#  [31] "blueviolet"           "brown"                "brown1"
#  [34] "brown2"               "brown3"               "brown4"
#  [37] "burlywood"            "burlywood1"           "burlywood2"
#  [40] "burlywood3"           "burlywood4"           "cadetblue"
#  [43] "cadetblue1"           "cadetblue2"           "cadetblue3"
# ...

# %%
col = rgb(0,0,0)

# %%
col = "FFFFFF"

# %%
plot(sin, xlim=c(0,4*pi), ylim=c(-1,1), lty=1, ylab="")
par(new=T)
plot(cos, xlim=c(0,4*pi), ylim=c(-1,1), lty=2, ylab="")
# Out:
# plot without title

# %%
kion <- read.table("kion.dat", header=T)

# %%
attach(kion)

# %%
plot(HEIKIN)
par(new=T)
plot(MAX)
par(new=T)
plot(MIN)
# Out:
# plot without title

# %%
plot(HEIKIN, ylim=c(0,35), ylab="", xlab="")
par(new=T)
plot(MAX, ylim=c(0,35), ylab="", xlab="")
par(new=T)
plot(MIN, ylim=c(0,35), ylab="", xlab="")
# Out:
# plot without title

# %%
plot(MAX~MIN, col=1)
abline(lm(MAX~MIN), col=2)
summary(lm(MAX~MIN))
# Out:
# Call:
# lm(formula = MAX ~ MIN)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.8162 -0.3071  0.2781  0.6175  1.3819
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  7.79590    0.57856   13.47 9.75e-08 ***
# MIN          0.97957    0.03925   24.96 2.44e-10 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.075 on 10 degrees of freedom
# Multiple R-squared:  0.9842,	Adjusted R-squared:  0.9826
# F-statistic:   623 on 1 and 10 DF,  p-value: 2.438e-10
# plot without title

# %%
plot(MIN, MAX)
abline(lsfit(MIN, MAX), col=2)
lsfit(MIN, MAX)
# Out:
# $coefficients
# Intercept         X
# 7.7959037 0.9795657
#
# $residuals
#  [1] -1.81620984 -0.03868759  0.80422449  0.55531029  1.00243741  0.31073932
#  [7] -1.74430517 -0.07074161  0.24547767  0.38608995  1.38187491 -1.01620984
#
# $intercept
# [1] TRUE
#
# $qr
# $qt
#  [1] -69.2242973  26.8309667   1.1520699   0.9293638   1.4519703   0.8158334
#  [7]  -1.2161480   0.4951552   0.7683932   0.8272362   1.7695567  -0.6788476
#
# $qr
#        Intercept            X
#  [1,] -3.4641016 -43.09919760
#  [2,]  0.2886751  27.39067664
#  [3,]  0.2886751   0.20548066
#  [4,]  0.2886751   0.11420873
#  [5,]  0.2886751  -0.14865444
#  [6,]  0.2886751  -0.34215093
#  [7,]  0.2886751  -0.42247023
#  [8,]  0.2886751  -0.55390182
#  [9,]  0.2886751  -0.40421585
# [10,]  0.2886751  -0.11944742
# [11,]  0.2886751   0.06674733
# [12,]  0.2886751   0.24198944
#
# $qraux
# [1] 1.288675 1.282149
#
# $rank
# [1] 2
#
# $pivot
# [1] 1 2
#
# $tol
# [1] 1e-07
#
# attr(,"class")
# [1] "qr"
# ...

# %%
library(psych)
pairs.panels(kion)
# Out:
# plot without title

# %%
1:5
# Out:
# [1] 1 2 3 4 5

# %%
-3:3
# Out:
# [1] -3 -2 -1  0  1  2  3

# %%
rep(1:3, length=8)
# Out:
# [1] 1 2 3 1 2 3 1 2

# %%
seq(1, 10, by=2)
# Out:
# [1] 1 3 5 7 9

# %%
seq(1, 10, length=5)
# Out:
# [1]  1.00  3.25  5.50  7.75 10.00

# %%
x<-seq(1,10,by=1)
plot(x,log(x))
# Out:
# plot without title

# %%
y<-seq(1,10,by=0.1)
plot(y,log(y))
# Out:
# plot without title

# %%
z<-seq(1,10,by=0.01)
plot(z,log(z))
# Out:
# plot without title
